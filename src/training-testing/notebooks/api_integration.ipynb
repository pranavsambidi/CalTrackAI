# %%
import requests
import time
import json
import pandas as pd
from rapidfuzz import fuzz, process
import re

# ---------------------------
# USDA API CONFIG
# ---------------------------

load_dotenv()                                     
api_key = os.getenv("USDA_API_KEY")               

if api_key is None:
    raise ValueError("USDA_API_KEY not found in .env file")
base_url = "https://api.nal.usda.gov/fdc/v1/foods/search"

# ---------------------------
# Food-101 labels (101 items)
# ---------------------------
food_101_labels = sorted(set([
    "apple_pie","baby_back_ribs","baklava","beef_carpaccio","beef_tartare",
    "beet_salad","beignets","bibimbap","bread_pudding","breakfast_burrito",
    "bruschetta","caesar_salad","cannoli","caprese_salad","carrot_cake",
    "ceviche","cheesecake","cheese_plate","chicken_curry","chicken_quesadilla",
    "chicken_wings","chocolate_cake","chocolate_mousse","churros","clam_chowder",
    "club_sandwich","crab_cakes","creme_brulee","croque_madame","cup_cakes",
    "deviled_eggs","donuts","dumplings","edamame","eggs_benedict","escargots",
    "falafel","filet_mignon","fish_and_chips","foie_gras","french_fries",
    "french_onion_soup","french_toast","fried_calamari","fried_rice","frozen_yogurt",
    "garlic_bread","gnocchi","greek_salad","grilled_cheese_sandwich","grilled_salmon",
    "guacamole","gyoza","hamburger","hot_and_sour_soup","hot_dog","huevos_rancheros",
    "hummus","ice_cream","lasagna","lobster_bisque","lobster_roll_sandwich","macaroni_and_cheese",
    "macarons","miso_soup","mussels","nachos","omelette","onion_rings","oysters",
    "pad_thai","paella","pancakes","panna_cotta","peking_duck","pho","pizza",
    "pork_chop","poutine","prime_rib","pulled_pork_sandwich","ramen","ravioli",
    "red_velvet_cake","risotto","samosa","sashimi","scallops","seaweed_salad",
    "shrimp_and_grits","spaghetti_bolognese","spaghetti_carbonara","spring_rolls",
    "steak","strawberry_shortcake","sushi","tacos","takoyaki","tiramisu","tuna_tartare","waffles"
]))

len(food_101_labels)
# Out:
# 101

# %%
# Cell 2: Synonyms and alternate search terms

synonyms = {
    "beef_carpaccio": "beef carpaccio",
    "beef_tartare": "steak tartare",
    "bibimbap": "korean rice bowl",
    "club_sandwich": "club sandwich",
    "croque_madame": "croque madame sandwich",
    "fish_and_chips": "fish and chips",
    "foie_gras": "duck liver pate",
    "gyoza": "gyoza dumplings",
    "lobster_roll_sandwich": "lobster roll",
    "omelette": "egg omelet",
    "oysters": "raw oysters",
    "pho": "vietnamese pho soup",
    "pork_chop": "grilled pork chop",
    "poutine": "poutine fries",
    "prime_rib": "prime rib roast",
    "spaghetti_bolognese": "spaghetti with meat sauce",
    "spring_rolls": "spring rolls",
    "sushi": "sushi rolls",
    "tacos": "mexican tacos",
    "takoyaki": "takoyaki balls",
    "tuna_tartare": "tuna tartare",
    "ramen": "japanese ramen noodle soup",
    "paella": "spanish paella",
    "samosa": "indian samosa",
    "ceviche": "fish ceviche",
    "panna_cotta": "panna cotta dessert",
    "beignets": "french beignets",
    "bruschetta": "bruschetta appetizer",
    "guacamole": "guacamole avocado dip",
    "falafel": "falafel balls",
    "lasagna": "lasagna with meat",
    "fried_rice": "fried rice"
}

# Extra, more descriptive variants
extra_synonyms = {
    "beef_carpaccio": "thinly sliced raw beef appetizer",
    "bibimbap": "korean mixed rice bowl with vegetables and egg",
    "club_sandwich": "layered chicken bacon sandwich",
    "croque_madame": "grilled ham and cheese sandwich with fried egg",
    "fish_and_chips": "battered fried fish served with potato fries",
    "foie_gras": "goose liver pate french delicacy",
    "omelette": "fluffy egg omelet with cheese",
    "oysters": "fresh raw oysters shellfish",
    "pho": "beef noodle soup vietnamese",
    "pork_chop": "fried pork meat with bone",
    "poutine": "canadian french fries with cheese curds and gravy",
    "prime_rib": "slow roasted beef rib cut",
    "spring_rolls": "crispy fried vegetable rolls",
    "sushi": "japanese rice rolls with fish",
    "tacos": "mexican tortilla with meat and vegetables",
    "takoyaki": "japanese octopus dough balls",
    "tuna_tartare": "raw minced tuna appetizer",
    "ramen": "japanese noodle soup",
    "paella": "spanish seafood rice dish",
    "samosa": "indian fried pastry with potato filling",
    "ceviche": "raw fish marinated in lemon juice",
    "panna_cotta": "italian creamy milk dessert",
    "beignets": "fried dough pastry french",
    "bruschetta": "grilled bread with tomato topping",
    "guacamole": "avocado dip",
    "falafel": "fried chickpea balls",
    "lasagna": "layered pasta with cheese and tomato sauce",
    "fried_rice": "stir fried rice with egg and vegetables"
}

# Merge extra_synonyms into synonyms
for k, v in extra_synonyms.items():
    # keep both versions as separate search terms later
    if k in synonyms:
        synonyms[k] = synonyms[k] + " || " + v
    else:
        synonyms[k] = v

synonyms
# Out:
# {'beef_carpaccio': 'beef carpaccio || thinly sliced raw beef appetizer',
#  'beef_tartare': 'steak tartare',
#  'bibimbap': 'korean rice bowl || korean mixed rice bowl with vegetables and egg',
#  'club_sandwich': 'club sandwich || layered chicken bacon sandwich',
#  'croque_madame': 'croque madame sandwich || grilled ham and cheese sandwich with fried egg',
#  'fish_and_chips': 'fish and chips || battered fried fish served with potato fries',
#  'foie_gras': 'duck liver pate || goose liver pate french delicacy',
#  'gyoza': 'gyoza dumplings',
#  'lobster_roll_sandwich': 'lobster roll',
#  'omelette': 'egg omelet || fluffy egg omelet with cheese',
#  'oysters': 'raw oysters || fresh raw oysters shellfish',
#  'pho': 'vietnamese pho soup || beef noodle soup vietnamese',
#  'pork_chop': 'grilled pork chop || fried pork meat with bone',
#  'poutine': 'poutine fries || canadian french fries with cheese curds and gravy',
#  'prime_rib': 'prime rib roast || slow roasted beef rib cut',
#  'spaghetti_bolognese': 'spaghetti with meat sauce',
#  'spring_rolls': 'spring rolls || crispy fried vegetable rolls',
#  'sushi': 'sushi rolls || japanese rice rolls with fish',
#  'tacos': 'mexican tacos || mexican tortilla with meat and vegetables',
#  'takoyaki': 'takoyaki balls || japanese octopus dough balls',
#  'tuna_tartare': 'tuna tartare || raw minced tuna appetizer',
#  'ramen': 'japanese ramen noodle soup || japanese noodle soup',
#  'paella': 'spanish paella || spanish seafood rice dish',
#  'samosa': 'indian samosa || indian fried pastry with potato filling',
#  'ceviche': 'fish ceviche || raw fish marinated in lemon juice',
#  'panna_cotta': 'panna cotta dessert || italian creamy milk dessert',
#  'beignets': 'french beignets || fried dough pastry french',
#  'bruschetta': 'bruschetta appetizer || grilled bread with tomato topping',
#  'guacamole': 'guacamole avocado dip || avocado dip',
#  'falafel': 'falafel balls || fried chickpea balls',
#  'lasagna': 'lasagna with meat || layered pasta with cheese and tomato sauce',
#  'fried_rice': 'fried rice || stir fried rice with egg and vegetables'}

# %%
# Cell 3: Helper functions

def normalize_text(text: str) -> str:
    """Lowercase, keep letters/spaces, collapse multiple spaces."""
    text = str(text).lower()
    text = re.sub(r'[^a-z\s]', ' ', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

def usda_search(query: str, page_size: int = 10):
    """Call USDA search API for a given query string."""
    params = {
        "query": query,
        "pageSize": page_size,
        "api_key": api_key
    }
    try:
        resp = requests.get(base_url, params=params)
        resp.raise_for_status()
        data = resp.json()
        return data.get("foods", [])
    except Exception as e:
        print(f"[ERROR] USDA API call failed for query='{query}': {e}")
        return []

def extract_nutrients(food_obj: dict):
    """Extract calories, protein, fat, carbs from a USDA food object."""
    nutrients_list = food_obj.get("foodNutrients", [])
    nutrients = {n.get("nutrientName"): n.get("value") for n in nutrients_list}

    calories = nutrients.get("Energy", None)
    protein = nutrients.get("Protein", None)
    fat = nutrients.get("Total lipid (fat)", None)
    carbs = nutrients.get("Carbohydrate, by difference", None)

    return calories, protein, fat, carbs

# %%
# Cell 4: Build search terms per label

label_to_search_terms = {}

for label in food_101_labels:
    base = label.replace("_", " ")
    terms = [base]

    # If we have synonyms, split the combined string into multiple terms
    if label in synonyms:
        syn_str = synonyms[label]
        for part in syn_str.split("||"):
            t = part.strip()
            if t:
                terms.append(t)

    # Remove duplicates while preserving order
    seen = set()
    uniq_terms = []
    for t in terms:
        if t not in seen:
            uniq_terms.append(t)
            seen.add(t)

    label_to_search_terms[label] = uniq_terms

# Quick sanity check for a few labels
for k in ["beef_carpaccio", "samosa", "tuna_tartare", "tacos"]:
    print(k, "->", label_to_search_terms.get(k))
# Out:
# beef_carpaccio -> ['beef carpaccio', 'thinly sliced raw beef appetizer']
# samosa -> ['samosa', 'indian samosa', 'indian fried pastry with potato filling']
# tuna_tartare -> ['tuna tartare', 'raw minced tuna appetizer']
# tacos -> ['tacos', 'mexican tacos', 'mexican tortilla with meat and vegetables']

# %%
# Cell 5: Download raw candidates for all Food-101 labels

all_rows = []

for label in food_101_labels:
    terms = label_to_search_terms[label]
    print(f"\n==== {label} ====")
    for q in terms:
        q_stripped = q.strip()
        if not q_stripped:
            continue

        print(f"  Querying USDA for: '{q_stripped}'")
        foods = usda_search(q_stripped, page_size=15)

        for f in foods:
            calories, protein, fat, carbs = extract_nutrients(f)
            row = {
                "source_label": label,
                "query_used": q_stripped,
                "fdcId": f.get("fdcId"),
                "description": f.get("description"),
                "dataType": f.get("dataType"),
                "calories": calories,
                "protein": protein,
                "fat": fat,
                "carbohydrates": carbs
            }
            all_rows.append(row)

        # be nice to the API
        time.sleep(0.25)

len(all_rows)
# Out:
# ==== apple_pie ====
#   Querying USDA for: 'apple pie'
#
# ==== baby_back_ribs ====
#   Querying USDA for: 'baby back ribs'
#
# ==== baklava ====
#   Querying USDA for: 'baklava'
#
# ==== beef_carpaccio ====
#   Querying USDA for: 'beef carpaccio'
#   Querying USDA for: 'thinly sliced raw beef appetizer'
#
# ==== beef_tartare ====
#   Querying USDA for: 'beef tartare'
#   Querying USDA for: 'steak tartare'
#
# ==== beet_salad ====
#   Querying USDA for: 'beet salad'
#
# ==== beignets ====
#   Querying USDA for: 'beignets'
#   Querying USDA for: 'french beignets'
#   Querying USDA for: 'fried dough pastry french'
#
# ==== bibimbap ====
#   Querying USDA for: 'bibimbap'
#   Querying USDA for: 'korean rice bowl'
#   Querying USDA for: 'korean mixed rice bowl with vegetables and egg'
#
# ==== bread_pudding ====
#   Querying USDA for: 'bread pudding'
#
# ==== breakfast_burrito ====
#   Querying USDA for: 'breakfast burrito'
#
# ==== bruschetta ====
#   Querying USDA for: 'bruschetta'
#   Querying USDA for: 'bruschetta appetizer'
#   Querying USDA for: 'grilled bread with tomato topping'
#
# ==== caesar_salad ====
#   Querying USDA for: 'caesar salad'
#
# ==== cannoli ====
#   Querying USDA for: 'cannoli'
#
# ==== caprese_salad ====
#   Querying USDA for: 'caprese salad'
#
# ==== carrot_cake ====
#   Querying USDA for: 'carrot cake'
#
# ==== ceviche ====
#   Querying USDA for: 'ceviche'
#   Querying USDA for: 'fish ceviche'
#   Querying USDA for: 'raw fish marinated in lemon juice'
#
# ==== cheese_plate ====
#   Querying USDA for: 'cheese plate'
#
# ==== cheesecake ====
#   Querying USDA for: 'cheesecake'
#
# ==== chicken_curry ====
#   Querying USDA for: 'chicken curry'
#
# ==== chicken_quesadilla ====
#   Querying USDA for: 'chicken quesadilla'
#
# ==== chicken_wings ====
#   Querying USDA for: 'chicken wings'
#
# ==== chocolate_cake ====
#   Querying USDA for: 'chocolate cake'
#
# ==== chocolate_mousse ====
#   Querying USDA for: 'chocolate mousse'
#
# ==== churros ====
#   Querying USDA for: 'churros'
#
# ==== clam_chowder ====
#   Querying USDA for: 'clam chowder'
#
# ==== club_sandwich ====
#   Querying USDA for: 'club sandwich'
#   Querying USDA for: 'layered chicken bacon sandwich'
#
# ==== crab_cakes ====
#   Querying USDA for: 'crab cakes'
#
# ==== creme_brulee ====
#   Querying USDA for: 'creme brulee'
#
# ==== croque_madame ====
#   Querying USDA for: 'croque madame'
#   Querying USDA for: 'croque madame sandwich'
#   Querying USDA for: 'grilled ham and cheese sandwich with fried egg'
#
# ==== cup_cakes ====
#   Querying USDA for: 'cup cakes'
#
# ==== deviled_eggs ====
#   Querying USDA for: 'deviled eggs'
#
# ==== donuts ====
#   Querying USDA for: 'donuts'
#
# ==== dumplings ====
#   Querying USDA for: 'dumplings'
#
# ==== edamame ====
#   Querying USDA for: 'edamame'
#
# ==== eggs_benedict ====
#   Querying USDA for: 'eggs benedict'
#
# ==== escargots ====
#   Querying USDA for: 'escargots'
#
# ==== falafel ====
#   Querying USDA for: 'falafel'
#   Querying USDA for: 'falafel balls'
#   Querying USDA for: 'fried chickpea balls'
#
# ==== filet_mignon ====
#   Querying USDA for: 'filet mignon'
#
# ==== fish_and_chips ====
#   Querying USDA for: 'fish and chips'
#   Querying USDA for: 'battered fried fish served with potato fries'
#
# ==== foie_gras ====
#   Querying USDA for: 'foie gras'
#   Querying USDA for: 'duck liver pate'
#   Querying USDA for: 'goose liver pate french delicacy'
#
# ==== french_fries ====
#   Querying USDA for: 'french fries'
#
# ==== french_onion_soup ====
#   Querying USDA for: 'french onion soup'
#
# ==== french_toast ====
#   Querying USDA for: 'french toast'
#
# ==== fried_calamari ====
#   Querying USDA for: 'fried calamari'
#
# ==== fried_rice ====
#   Querying USDA for: 'fried rice'
#   Querying USDA for: 'stir fried rice with egg and vegetables'
#
# ==== frozen_yogurt ====
#   Querying USDA for: 'frozen yogurt'
#
# ==== garlic_bread ====
#   Querying USDA for: 'garlic bread'
#
# ==== gnocchi ====
#   Querying USDA for: 'gnocchi'
#
# ==== greek_salad ====
#   Querying USDA for: 'greek salad'
#
# ==== grilled_cheese_sandwich ====
#   Querying USDA for: 'grilled cheese sandwich'
#
# ==== grilled_salmon ====
#   Querying USDA for: 'grilled salmon'
#
# ==== guacamole ====
#   Querying USDA for: 'guacamole'
#   Querying USDA for: 'guacamole avocado dip'
#   Querying USDA for: 'avocado dip'
#
# ==== gyoza ====
#   Querying USDA for: 'gyoza'
#   Querying USDA for: 'gyoza dumplings'
#
# ==== hamburger ====
#   Querying USDA for: 'hamburger'
#
# ==== hot_and_sour_soup ====
#   Querying USDA for: 'hot and sour soup'
#
# ==== hot_dog ====
#   Querying USDA for: 'hot dog'
#
# ==== huevos_rancheros ====
#   Querying USDA for: 'huevos rancheros'
#
# ==== hummus ====
#   Querying USDA for: 'hummus'
#
# ==== ice_cream ====
#   Querying USDA for: 'ice cream'
#
# ==== lasagna ====
#   Querying USDA for: 'lasagna'
#   Querying USDA for: 'lasagna with meat'
#   Querying USDA for: 'layered pasta with cheese and tomato sauce'
#
# ==== lobster_bisque ====
#   Querying USDA for: 'lobster bisque'
#
# ==== lobster_roll_sandwich ====
#   Querying USDA for: 'lobster roll sandwich'
#   Querying USDA for: 'lobster roll'
#
# ==== macaroni_and_cheese ====
#   Querying USDA for: 'macaroni and cheese'
#
# ==== macarons ====
#   Querying USDA for: 'macarons'
#
# ==== miso_soup ====
#   Querying USDA for: 'miso soup'
#
# ==== mussels ====
#   Querying USDA for: 'mussels'
#
# ==== nachos ====
#   Querying USDA for: 'nachos'
#
# ==== omelette ====
#   Querying USDA for: 'omelette'
#   Querying USDA for: 'egg omelet'
#   Querying USDA for: 'fluffy egg omelet with cheese'
#
# ==== onion_rings ====
#   Querying USDA for: 'onion rings'
#
# ==== oysters ====
#   Querying USDA for: 'oysters'
#   Querying USDA for: 'raw oysters'
#   Querying USDA for: 'fresh raw oysters shellfish'
#
# ==== pad_thai ====
#   Querying USDA for: 'pad thai'
#
# ==== paella ====
#   Querying USDA for: 'paella'
#   Querying USDA for: 'spanish paella'
#   Querying USDA for: 'spanish seafood rice dish'
#
# ==== pancakes ====
#   Querying USDA for: 'pancakes'
#
# ==== panna_cotta ====
#   Querying USDA for: 'panna cotta'
#   Querying USDA for: 'panna cotta dessert'
#   Querying USDA for: 'italian creamy milk dessert'
#
# ==== peking_duck ====
#   Querying USDA for: 'peking duck'
#
# ==== pho ====
#   Querying USDA for: 'pho'
#   Querying USDA for: 'vietnamese pho soup'
#   Querying USDA for: 'beef noodle soup vietnamese'
#
# ==== pizza ====
#   Querying USDA for: 'pizza'
#
# ==== pork_chop ====
#   Querying USDA for: 'pork chop'
#   Querying USDA for: 'grilled pork chop'
#   Querying USDA for: 'fried pork meat with bone'
#
# ==== poutine ====
#   Querying USDA for: 'poutine'
#   Querying USDA for: 'poutine fries'
#   Querying USDA for: 'canadian french fries with cheese curds and gravy'
#
# ==== prime_rib ====
#   Querying USDA for: 'prime rib'
#   Querying USDA for: 'prime rib roast'
#   Querying USDA for: 'slow roasted beef rib cut'
#
# ==== pulled_pork_sandwich ====
#   Querying USDA for: 'pulled pork sandwich'
#
# ==== ramen ====
#   Querying USDA for: 'ramen'
#   Querying USDA for: 'japanese ramen noodle soup'
#   Querying USDA for: 'japanese noodle soup'
#
# ==== ravioli ====
#   Querying USDA for: 'ravioli'
#
# ==== red_velvet_cake ====
#   Querying USDA for: 'red velvet cake'
#
# ==== risotto ====
#   Querying USDA for: 'risotto'
#
# ==== samosa ====
#   Querying USDA for: 'samosa'
#   Querying USDA for: 'indian samosa'
#   Querying USDA for: 'indian fried pastry with potato filling'
#
# ==== sashimi ====
#   Querying USDA for: 'sashimi'
#
# ==== scallops ====
#   Querying USDA for: 'scallops'
#
# ==== seaweed_salad ====
#   Querying USDA for: 'seaweed salad'
#
# ==== shrimp_and_grits ====
#   Querying USDA for: 'shrimp and grits'
#
# ==== spaghetti_bolognese ====
#   Querying USDA for: 'spaghetti bolognese'
#   Querying USDA for: 'spaghetti with meat sauce'
#
# ==== spaghetti_carbonara ====
#   Querying USDA for: 'spaghetti carbonara'
#
# ==== spring_rolls ====
#   Querying USDA for: 'spring rolls'
#   Querying USDA for: 'crispy fried vegetable rolls'
#
# ==== steak ====
#   Querying USDA for: 'steak'
#
# ==== strawberry_shortcake ====
#   Querying USDA for: 'strawberry shortcake'
#
# ==== sushi ====
#   Querying USDA for: 'sushi'
#   Querying USDA for: 'sushi rolls'
#   Querying USDA for: 'japanese rice rolls with fish'
#
# ==== tacos ====
#   Querying USDA for: 'tacos'
#   Querying USDA for: 'mexican tacos'
#   Querying USDA for: 'mexican tortilla with meat and vegetables'
#
# ==== takoyaki ====
#   Querying USDA for: 'takoyaki'
#   Querying USDA for: 'takoyaki balls'
#   Querying USDA for: 'japanese octopus dough balls'
#
# ==== tiramisu ====
#   Querying USDA for: 'tiramisu'
# ==== tuna_tartare ====
#   Querying USDA for: 'tuna tartare'
#   Querying USDA for: 'raw minced tuna appetizer'
#
# ==== waffles ====
#   Querying USDA for: 'waffles'
# 2264

# %%
# Cell 6: Save raw candidate table & quick inspection

raw_df = pd.DataFrame(all_rows)

print("Total candidate rows:", len(raw_df))
print("Unique Food-101 labels in candidates:", raw_df["source_label"].nunique())

# Normalize description for later fuzzy matching
raw_df["normalized_description"] = raw_df["description"].astype(str).apply(normalize_text)

# Save raw candidates for debugging / backup
raw_df.to_csv("../data/raw/usda_food_candidates_raw.csv", index=False)

raw_df.head()
# Out:
# Total candidate rows: 2264
# Unique Food-101 labels in candidates: 101
#   source_label query_used    fdcId description dataType  calories  protein  \
# 0    apple_pie  apple pie  2084465   APPLE PIE  Branded     300.0    33.30
# 1    apple_pie  apple pie  1916963   APPLE PIE  Branded     276.0     3.25
# 2    apple_pie  apple pie  2288447   APPLE PIE  Branded     354.0     1.77
# 3    apple_pie  apple pie  2063662   APPLE PIE  Branded     211.0     1.32
# 4    apple_pie  apple pie  2063720   APPLE PIE  Branded     254.0     2.31
#
#      fat  carbohydrates normalized_description
# 0   8.33           41.7              apple pie
# 1   8.13           46.3              apple pie
# 2  15.00           54.0              apple pie
# 3  11.00           29.1              apple pie
# 4  12.30           33.1              apple pie

# %%
# Cell 7: Fuzzy matching to select the best row per Food-101 label

final_rows = []
all_norm_descriptions = raw_df["normalized_description"].tolist()

for label in food_101_labels:
    candidates = raw_df[raw_df["source_label"] == label].copy()

    # Build target texts for scoring (base label + all search terms)
    base = label.replace("_", " ")
    terms = label_to_search_terms[label]
    targets = [normalize_text(t) for t in ([base] + terms)]

    def score_candidate(desc_norm: str) -> int:
        # Score = max token_sort_ratio against any target
        return max(fuzz.token_sort_ratio(desc_norm, t) for t in targets)

    if not candidates.empty:
        # Compute scores within candidates of this label
        candidates["match_score"] = candidates["normalized_description"].apply(score_candidate)

        best_row = candidates.sort_values("match_score", ascending=False).iloc[0]
        final_rows.append(best_row.to_dict())
        print(f"[OK] Label '{label}' matched with '{best_row['description']}' (score={best_row['match_score']})")
    else:
        # Fallback: search globally in all rows
        print(f"[WARN] No direct candidates for '{label}'. Using global fuzzy search.")
        # Build one combined query string from terms
        combined_query = base
        # use process.extractOne on all normalized descriptions
        match = process.extractOne(combined_query, all_norm_descriptions, scorer=fuzz.token_sort_ratio)
        if match:
            best_desc_norm = match[0]
            row = raw_df[raw_df["normalized_description"] == best_desc_norm].iloc[0]
            row = row.copy()
            row["match_score"] = match[1]
            # override source_label to correct label
            row["source_label"] = label
            final_rows.append(row.to_dict())
            print(f"   -> matched to '{row['description']}' (score={row['match_score']})")
        else:
            print(f"[ERROR] Could not match ANY USDA row for label '{label}'")

len(final_rows)
# Out:
# [OK] Label 'apple_pie' matched with 'APPLE PIE' (score=100.0)
# [OK] Label 'baby_back_ribs' matched with 'BABY BACK RIBS' (score=100.0)
# [OK] Label 'baklava' matched with 'Baklava' (score=100.0)
# [OK] Label 'beef_carpaccio' matched with 'THINLY SLICED BEEF' (score=72.0)
# [OK] Label 'beef_tartare' matched with 'Steak tartare' (score=100.0)
# [OK] Label 'beet_salad' matched with 'BEET SALAD' (score=100.0)
# [OK] Label 'beignets' matched with 'Beignet' (score=93.33333333333333)
# [OK] Label 'bibimbap' matched with 'Bibimbap, Korean' (score=69.56521739130434)
# [OK] Label 'bread_pudding' matched with 'BREAD PUDDING' (score=100.0)
# [OK] Label 'breakfast_burrito' matched with 'BREAKFAST BURRITO' (score=100.0)
# [OK] Label 'bruschetta' matched with 'Bruschetta' (score=100.0)
# [OK] Label 'caesar_salad' matched with 'CAESAR SALAD' (score=100.0)
# [OK] Label 'cannoli' matched with 'CANNOLI' (score=100.0)
# [OK] Label 'caprese_salad' matched with 'CAPRESE SALAD' (score=100.0)
# [OK] Label 'carrot_cake' matched with 'CARROT CAKE' (score=100.0)
# [OK] Label 'ceviche' matched with 'Ceviche' (score=100.0)
# [OK] Label 'cheese_plate' matched with 'SPANISH CHEESE PLATE' (score=75.0)
# [OK] Label 'cheesecake' matched with 'CHEESECAKE' (score=100.0)
# [OK] Label 'chicken_curry' matched with 'Chicken curry' (score=100.0)
# [OK] Label 'chicken_quesadilla' matched with 'CHICKEN QUESADILLA' (score=100.0)
# [OK] Label 'chicken_wings' matched with 'CHICKEN WINGS' (score=100.0)
# [OK] Label 'chocolate_cake' matched with 'CHOCOLATE CAKE' (score=100.0)
# [OK] Label 'chocolate_mousse' matched with 'CHOCOLATE MOUSSE' (score=100.0)
# [OK] Label 'churros' matched with 'Churros' (score=100.0)
# [OK] Label 'clam_chowder' matched with 'CLAM CHOWDER' (score=100.0)
# [OK] Label 'club_sandwich' matched with 'Cuban sandwich' (score=88.88888888888889)
# [OK] Label 'crab_cakes' matched with 'CRAB CAKES' (score=100.0)
# [OK] Label 'creme_brulee' matched with 'Creme brulee' (score=100.0)
# [OK] Label 'croque_madame' matched with 'GRILLED HAM & CHEESE SANDWICH, GRILLED HAM & CHEESE' (score=73.91304347826086)
# [OK] Label 'cup_cakes' matched with 'CUP CAKES' (score=100.0)
# [OK] Label 'deviled_eggs' matched with 'DEVILED EGGS' (score=100.0)
# [OK] Label 'donuts' matched with 'DONUTS' (score=100.0)
# [OK] Label 'dumplings' matched with 'DUMPLINGS' (score=100.0)
# [OK] Label 'edamame' matched with 'EDAMAME' (score=100.0)
# [OK] Label 'eggs_benedict' matched with 'Egg, Benedict' (score=96.0)
# [OK] Label 'escargots' matched with 'Escargot' (score=94.11764705882352)
# [OK] Label 'falafel' matched with 'Falafel' (score=100.0)
# [OK] Label 'filet_mignon' matched with 'FILET MIGNON' (score=100.0)
# [OK] Label 'fish_and_chips' matched with 'Fish, anchovy' (score=69.23076923076923)
# [OK] Label 'foie_gras' matched with 'LIVER PATE' (score=80.0)
# [OK] Label 'french_fries' matched with 'FRENCH FRIES' (score=100.0)
# [OK] Label 'french_onion_soup' matched with 'FRENCH ONION SOUP' (score=100.0)
# [OK] Label 'french_toast' matched with 'FRENCH TOAST' (score=100.0)
# [OK] Label 'fried_calamari' matched with 'Calamari, fried' (score=100.0)
# [OK] Label 'fried_rice' matched with 'FRIED RICE' (score=100.0)
# [OK] Label 'frozen_yogurt' matched with 'FROZEN YOGURT' (score=100.0)
# [OK] Label 'garlic_bread' matched with 'GARLIC BREAD' (score=100.0)
# [OK] Label 'gnocchi' matched with 'GNOCCHI' (score=100.0)
# [OK] Label 'greek_salad' matched with 'GREEK SALAD' (score=100.0)
# [OK] Label 'grilled_cheese_sandwich' matched with 'GRILLED CHEESE SANDWICH' (score=100.0)
# [OK] Label 'grilled_salmon' matched with 'GRILLED SALMON' (score=100.0)
# [OK] Label 'guacamole' matched with 'GUACAMOLE' (score=100.0)
# [OK] Label 'gyoza' matched with 'VEGETABLE GYOZA DUMPLINGS' (score=75.0)
# [OK] Label 'hamburger' matched with 'HAMBURGER' (score=100.0)
# [OK] Label 'hot_and_sour_soup' matched with 'Soup, hot and sour' (score=100.0)
# [OK] Label 'hot_dog' matched with 'HOT DOG' (score=100.0)
# [OK] Label 'huevos_rancheros' matched with 'Huevos rancheros' (score=100.0)
# [OK] Label 'hummus' matched with 'HUMMUS' (score=100.0)
# [OK] Label 'ice_cream' matched with 'ICE CREAM' (score=100.0)
# [OK] Label 'lasagna' matched with 'LASAGNA' (score=100.0)
# [OK] Label 'lobster_bisque' matched with 'LOBSTER BISQUE' (score=100.0)
# [OK] Label 'lobster_roll_sandwich' matched with 'LOBSTER EGG ROLL' (score=85.71428571428572)
# [OK] Label 'macaroni_and_cheese' matched with 'MACARONI AND CHEESE' (score=100.0)
# [OK] Label 'macarons' matched with 'MACARONS' (score=100.0)
# [OK] Label 'miso_soup' matched with 'MISO SOUP' (score=100.0)
# [OK] Label 'mussels' matched with 'Mussels' (score=100.0)
# [OK] Label 'nachos' matched with 'Nachos, NFS' (score=75.0)
# [OK] Label 'omelette' matched with 'Egg white, omelet, scrambled, or fried, with cheese' (score=63.1578947368421)
# [OK] Label 'onion_rings' matched with 'ONION RINGS' (score=100.0)
# [OK] Label 'oysters' matched with 'Oysters, raw' (score=100.0)
# [OK] Label 'pad_thai' matched with 'PAD THAI' (score=100.0)
# [OK] Label 'paella' matched with 'PAELLA' (score=100.0)
# [OK] Label 'pancakes' matched with 'PANCAKES' (score=100.0)
# [OK] Label 'panna_cotta' matched with 'Creamy Italian dressing' (score=76.0)
# [OK] Label 'peking_duck' matched with 'Duck, Peking' (score=100.0)
# [OK] Label 'pho' matched with 'ASSI, VIETNAMESE NOODLE SOUP' (score=85.18518518518519)
# [OK] Label 'pizza' matched with 'PIZZA' (score=100.0)
# [OK] Label 'pork_chop' matched with 'Pork, chop, stuffed' (score=69.23076923076923)
# [OK] Label 'poutine' matched with 'POUTINE POPPERS' (score=71.42857142857143)
# [OK] Label 'prime_rib' matched with 'SLOW ROASTED BEEF, ROAST BEEF' (score=75.47169811320755)
# [OK] Label 'pulled_pork_sandwich' matched with 'PULLED PORK SANDWICH, MILD BBQ' (score=81.63265306122449)
# [OK] Label 'ramen' matched with 'RAMEN' (score=100.0)
# [OK] Label 'ravioli' matched with 'RAVIOLI' (score=100.0)
# [OK] Label 'red_velvet_cake' matched with 'RED VELVET CAKE' (score=100.0)
# [OK] Label 'risotto' matched with 'RISOTTO' (score=100.0)
# [OK] Label 'samosa' matched with 'Samosa' (score=100.0)
# [OK] Label 'sashimi' matched with 'SASHIMI' (score=100.0)
# [OK] Label 'scallops' matched with 'SCALLOPS' (score=100.0)
# [OK] Label 'seaweed_salad' matched with 'SEAWEED SALAD' (score=100.0)
# [OK] Label 'shrimp_and_grits' matched with 'SHRIMP AND GRITS' (score=100.0)
# [OK] Label 'spaghetti_bolognese' matched with 'SPAGHETTI WITH MEAT SAUCE' (score=100.0)
# [OK] Label 'spaghetti_carbonara' matched with 'CREAMY CARBONARA SPAGHETTI' (score=84.44444444444444)
# [OK] Label 'spring_rolls' matched with 'FRIED VEGETABLE SPRING ROLL, FRIED VEGETABLE' (score=67.6056338028169)
# [OK] Label 'steak' matched with 'STEAK' (score=100.0)
# [OK] Label 'strawberry_shortcake' matched with 'STRAWBERRY SHORTCAKE' (score=100.0)
# [OK] Label 'sushi' matched with 'Sushi roll, eel' (score=80.0)
# [OK] Label 'tacos' matched with 'Toddler meal, meat and vegetables' (score=71.23287671232876)
# [OK] Label 'takoyaki' matched with 'Octopus (Alaska Native)' (score=57.14285714285714)
# [OK] Label 'tiramisu' matched with 'Tiramisu' (score=100.0)
# [OK] Label 'tuna_tartare' matched with 'Steak tartare' (score=56.00000000000001)
# [OK] Label 'waffles' matched with 'WAFFLES' (score=100.0)
# 101

# %%
# Cell 8: Build and save final USDA dataset (one row per Food-101 label)

final_df = pd.DataFrame(final_rows)

# For clarity, create a column 'query' that is just the human-readable food name
final_df["query"] = final_df["source_label"].apply(lambda x: x.replace("_", " "))

# Reorder columns (you can adjust as you like)
final_df = final_df[[
    "query",
    "fdcId",
    "description",
    "dataType",
    "calories",
    "protein",
    "fat",
    "carbohydrates",
    "source_label",
    "query_used",
    "match_score"
]]

print("Final rows:", len(final_df))
print("Unique labels:", final_df["source_label"].nunique())

# Save as the main CSV your backend & notebooks will use
final_df.to_csv("../data/raw/usda_food_data.csv", index=False)

final_df.head(10)
# Out:
# Final rows: 101
# Unique labels: 101
#                query    fdcId         description        dataType  calories  \
# 0          apple pie  2084465           APPLE PIE         Branded     300.0
# 1     baby back ribs  1457876      BABY BACK RIBS         Branded     170.0
# 2            baklava  2708044             Baklava  Survey (FNDDS)     440.0
# 3     beef carpaccio  2660667  THINLY SLICED BEEF         Branded     179.0
# 4       beef tartare  2706394       Steak tartare  Survey (FNDDS)     216.0
# 5         beet salad  1922885          BEET SALAD         Branded      93.0
# 6           beignets  2708071             Beignet  Survey (FNDDS)     417.0
# 7           bibimbap  2708950    Bibimbap, Korean  Survey (FNDDS)      76.0
# 8      bread pudding  2381798       BREAD PUDDING         Branded     222.0
# 9  breakfast burrito  2315891   BREAKFAST BURRITO         Branded     198.0
#
#    protein    fat  carbohydrates       source_label  \
# 0    33.30   8.33          41.70          apple_pie
# 1    18.80   9.82           0.00     baby_back_ribs
# 2     6.58  29.34          37.55            baklava
# 3    14.30  12.90           1.43     beef_carpaccio
# 4    17.45  15.60           0.34       beef_tartare
# 5     1.32   5.29          11.00         beet_salad
# 6     5.46  20.18          53.69           beignets
# 7     5.50   2.44           8.11           bibimbap
# 8     4.04   4.55          42.40      bread_pudding
# 9     8.13   7.77          26.20  breakfast_burrito
#
#                          query_used  match_score
# 0                         apple pie   100.000000
# 1                    baby back ribs   100.000000
# 2                           baklava   100.000000
# 3  thinly sliced raw beef appetizer    72.000000
# 4                      beef tartare   100.000000
# 5                        beet salad   100.000000
# 6                          beignets    93.333333
# 7                          bibimbap    69.565217
# 8                     bread pudding   100.000000
# 9                 breakfast burrito   100.000000

# %%
# Cell 9: Verification that all 101 labels are covered

present_labels = set(final_df["source_label"].tolist())
missing = [lbl for lbl in food_101_labels if lbl not in present_labels]

print("Missing labels:", missing)
print("Count missing:", len(missing))
# Out:
# Missing labels: []
# Count missing: 0
